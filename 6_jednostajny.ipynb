# %% [markdown]
# # Rozkład jednostajny na odcinku $[a,b]$
# Gęstość zmiennej losowej $X$ o rozkładzie jednostajnym na odcinku $[a,b]$ jest dana przez
# $$
# \chi_{[a,b]}(x) = \left\{ \begin{array}{ll}
# \frac{1}{b-a} & \textrm{gdy}  x \in [a,b]\\
# 0 & \textrm{gdy } x \notin [a,b]
# \end{array} \right. ,
# $$
# gdzie $a<b$ oraz $a,b \in \mathbb{R}$.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns

# %% [markdown]
# # Definiujemy zmienną losową

# %%
a = -1
width = 3
uniform = stats.uniform(a, width)

# %% [markdown]
# # Narysujmy gętość zmiennej losowej

# %%
fix, ax = plt.subplots(1,1)
x = np.arange(-5, 5, 0.05)
plt.plot(x, stats.uniform.pdf(x, a, width))
plt.show()

# %% [markdown]
# # Narysujmy dystrybuantę zmiennej losowej

# %%
fix, ax = plt.subplots(1,1)
x = np.arange(-5, 5, 0.05)
plt.plot(x, stats.uniform.cdf(x, a, 5))
plt.show()

# %% [markdown]
# # Wylosujmy próbkę i narysujmy histogram oraz gęstość na jednym obrazku

# %%
fix, ax = plt.subplots(1,1)
trails = uniform.rvs(2000000)
ax.hist(trails, density=True, alpha=0.5, bins=100)
ax.plot(x,stats.uniform.pdf(x,a,width),color="red")
ax.set_ylabel("PDF")
plt.show()

# %%
fix, ax = plt.subplots(1, 1)
ax.hist() # histogram z wylosowanej próby
ax.plot() # gęstość
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-b20d91d464bf> in <module>
#       1 fix, ax = plt.subplots(1, 1)
# ----> 2 ax.hist() # histogram z wylosowanej próby
#       3 ax.plot() # gęstość
#
# ~/projects/sages/sages_statystyka1/.statystyka1/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# -> 1438             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1439
#    1440         bound = new_sig.bind(ax, *args, **kwargs)
#
# TypeError: hist() missing 1 required positional argument: 'x'

# %% [markdown]
# # Narysujmy gęstości rozkładu jednostajnego z różnymi parametrami

# %% [markdown]
# # Narysujmy kilka histogramów różnych próbek z rozkładu jednostajnego o tych samych parametrach.

# %%
uniform = stats.uniform(0,1)

fix, ax = plt.subplots(nrows=5, ncols=5, figsize=(10,10))

for i in np.arange(0,5):
    for j in np.arange(0,5):
        x = uniform.rvs(100*(i+1)*(j+1))
        ax[i,j].hist(x, density=True)
        
plt.show()
