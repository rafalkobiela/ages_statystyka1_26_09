# %% [markdown]
# # Rozkład Poissona
# Rozkład prawdopodobieństwa zmiennej losowej $X$ o rozkładzie Poissona z parametrem $\lambda > 0$ wyraża się wzorem:
# $$
# P(X = k) = e^{-\lambda} \cdot \frac{\lambda^{k}}{k!}.
# $$

# %%
from scipy import stats
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Zadanie
# Proszę:
# <ul>
# <li> zdefiniuj zmienną losową o rozkładzie  Poissona $\lambda=2$ </li>,
# <li> narysuj dla niej gęstość i dystrybuantę </li>,
# <li> wylosuj próbkę i narysuj histogram </li>,
# <li> narysuj kilka gęstości rozkładu Poissona $\lambda=1,4,10$ </li>,
# <li> policz skośność i kurtozę dla gęstości Poissona $\lambda=1,4,10$</li>
# <\ul>

# %% [markdown]
# Zdefiniuj zmienną losową o rozkładzie Poissona  $\lambda=2$

# %%
pois_dist = stats.poisson(2)

# %% [markdown]
# Narysuj gęstość zmiennej losowej o rozkładzie Poissona

# %%
l = 5
x = np.arange(0, 20)
stats.poisson.pmf(x, l)
# Out:
# array([6.73794700e-03, 3.36897350e-02, 8.42243375e-02, 1.40373896e-01,
#        1.75467370e-01, 1.75467370e-01, 1.46222808e-01, 1.04444863e-01,
#        6.52780393e-02, 3.62655774e-02, 1.81327887e-02, 8.24217669e-03,
#        3.43424029e-03, 1.32086165e-03, 4.71736303e-04, 1.57245434e-04,
#        4.91391982e-05, 1.44527054e-05, 4.01464038e-06, 1.05648431e-06])

# %%
l = 5
fig, ax = plt.subplots(1,1)
x = np.arange(0, 20)
ax.set_xlim([-0.5, 20])
ax.set_ylim([0,1])
ax.plot(x, stats.poisson.pmf(x, l), 'bo')
ax.vlines(x, 0, stats.poisson.pmf(x, l), colors='b', lw=5, alpha=0.5)
plt.show()

# %% [markdown]
# Wylosuj próbkę i narysuj histogram

# %%
trails = pois_dist.rvs(1000)
plt.hist(trails, bins=20)
plt.show()

# %% [markdown]
# Narysuj dystrybuantę zmiennej losowej o rozkładzie Poissona

# %%
l = 3
fig, ax = plt.subplots(1,1)
x = np.arange(-5, 10+1 , 0.01)
ax.set_xlim([-0.5, 10+0.5])
ax.set_ylim([-0.2,1.2])
ax.plot(x, stats.poisson.cdf(x, l), 'bo--')
plt.show()

# %% [markdown]
# Policz momenty

# %%
l = 3

mean, var, skew, kurt = stats.poisson.stats(l, moments='mvsk')
print(mean)
print(var)
print(skew)
print(kurt)
# Out:
# 3.0
# 3.0
# 0.5773502691896257
# 0.3333333333333333

# %% [markdown]
# Narysuj gętość zmiennej losowej dla różnych parametrów

# %%
def get_cmap(n, name='hsv'):
    '''Returns a function that maps each index in 0, 1, ..., n-1 to a distinct 
    RGB color; the keyword argument name must be a standard mpl colormap name.'''
    return plt.cm.get_cmap(name, n)
#https://exceptionshub.com/how-to-generate-random-colors-in-matplotlib.html
fig, ax = plt.subplots(1,1)
x=np.arange(0,20)
cmap=get_cmap(40)

for l in np.arange(3,8):
    ax.plot(x,stats.poisson.pmf(x, l),'bo--', label=f'lambda={l}', color=cmap(l**2))
ax.legend()
