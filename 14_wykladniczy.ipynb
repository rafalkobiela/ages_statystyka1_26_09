# %% [markdown]
# # Rozkład wykładniczy
#
# Rozkład wykładniczy ma gęstość:
#
# $$
# f_{X}(x) =
# \left\{ \begin{array}{ll}
# \lambda e^{-\lambda x} & \textrm{gdy $x \geq 0$}\\
# 0 & \textrm{gdy $x < 0$}
# \end{array} \right. ,
# $$
#
# gdzie $k>0$ jest parametrem kształtu oraz $\lambda> 0$ jest parametrem skali.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns

# %% [markdown]
# # Definiujemy zmienną losową

# %% [markdown]
# pdf = lambda * exp(-lambda * x)

# %% [markdown]
# # Narysujmy gęstość zmiennej losowej

# %%
def exp_dist(x, l):
    return l * np.exp(-x * l)

# %%
exp_dist_vec = np.vectorize(exp_dist)

# %%
x = np.linspace(0, 2, 100)
plt.plot(x, exp_dist_vec(x, 1))
plt.show()

# %% [markdown]
# # Narysujmy dystrybuantę zmiennej losowej

# %% [markdown]
# # Wylosujmy próbkę i narysujmy histogram na jednym obrazku

# %% [markdown]
# # Narysujmy gęstości rozkładu jednostajnego z różnymi parametrami

# %%
def get_cmap(n, name='hsv'):
    return plt.cm.get_cmap(name, n)

fig, ax = plt.subplots(1,1, figsize = (10, 10))
x=np.arange(0, 0.4, 0.01)
cmap=get_cmap(400)

for l in np.arange(5, 55, 10):
    ax.plot(x, exp_dist_vec(x, l), label=f'lambda={l}', color=cmap(l*5))
ax.legend()

# %% [markdown]
# # Narysujmy kilka histogramów różnych próbek z rozkładu jednostajnego o tych samych parametrach.
